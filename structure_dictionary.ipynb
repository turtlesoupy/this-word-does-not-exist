# %%
# %load_ext autoreload
# %autoreload 2
import dictionary_definition
import random
import pickle

# %%
dictionary_path = "data/com_apple_MobileAsset_DictionaryServices_dictionaryOSX/69b7ab1cf0f75ad16bf6662b0a77fbfd36b7941f.asset/AssetData/New Oxford American Dictionary.dictionary/Contents/Resources/Body.data"
parsed = []
num_tried = 0
error_titles = []

with open(dictionary_path, "rb") as f:
    for entry in dictionary_definition.DictionaryDefinition.gen_from_apple_dictionary(f):
        num_tried += 1
        try:
            parsed.append(dictionary_definition.AppleDictParser.parse(entry.parsed_entry))
        except dictionary_definition.InvalidParseAssumptionError: 
            error_titles.append(title)
    
print(f"Error rate: {len(error_titles) / num_tried}")
# Out:
# Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0006560.016" role="text">Acids are compounds that release hydrogen ions (H<span class="sup">+</span>) when dissolved in water. Any solution with a pH of less than 7 is acidic, strong acids such as sulfuric or hydrochloric acid having a pH as low as 1 or 2. Most organic acids (<span class="ll" id="m_en_gbus0006560.017">carboxylic</span> or <span class="ll" id="m_en_gbus0006560.018">fatty acids</span>) contain the carboxyl group −COOH<span class="gp tg_note">.</span></span>
# WARNING:root:Too many topics found: [<span class="lg">or <span class="ge">Scottish </span></span>, <span class="lg" role="text"><span class="ge">British </span></span>], picking first one
# WARNING:root:Too many topics found: [<span class="lg">or <span class="ge">US</span></span>, <span class="lg" role="text"><span class="sj">Farming </span></span>], picking first one
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0151780.017" role="text">Compounds of carbon (organic compounds) form the physical basis of all living organisms. Carbon atoms are able to link with each other and with other atoms to form chains and rings, and an infinite variety of carbon compounds exist<span class="gp tg_note">.</span></span>
# WARNING:root:Too many topics found: [<span class="lg">or <span class="ge">British </span></span>, <span class="lg">or <span class="ge">US </span></span>], picking first one
# /root/miniconda3/envs/company-makeup/lib/python3.7/site-packages/bs4/__init__.py:314: UserWarning: "b'data'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# WARNING:dictionary_definition:Silently ignoring example without corresponding definition <span class="msDict x_xd1 hasSn t_subsense" d:abs="1" id="m_en_gbus0360630.034"><span class="gp sn tg_msDict" role="text">  • </span><span class="eg" role="text"><span class="gg" role="text"><span class="gp tg_gg">[</span>no <span class="sy">object</span><span class="gp tg_gg">] </span></span><span class="ex"><span class="lbl">:  </span>we fought and died for this country</span><span class="gp tg_eg">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:dictionary_definition:Dropping unexpected msDict in sense <span class="msDict x_xd1 t_core" id="m_en_gbus0428830.004"><span class="df" role="text">in nouns denoting<span class="gp tg_df">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0555550.012" role="text">Restrictions on the foods suitable for Jews are derived from rules in the books of Leviticus and Deuteronomy. Animals must be slaughtered and prepared in the prescribed way, in which the blood is drained from the body, while certain creatures, notably pigs and shellfish, are forbidden altogether. Meat and milk must not be cooked or consumed together, and separate utensils must be kept for each. Strict observance of these rules is today confined mainly to Orthodox Jews<span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0832580.021" role="text">Pygmies (e.g., the Mbuti and Twa peoples) are typically dark-skinned, nomadic hunter-gatherers with an average male height not above 150 cm (4 ft. 11 in.)<span class="xrg">. See also <span class="xr"><a href="x-dictionary:r:m_en_gbus0683870:com.apple.dictionary.NOAD:Negrillo" title="Negrillo">Negrillo</a></span>, <span class="xr"><a href="x-dictionary:r:m_en_gbus0683890:com.apple.dictionary.NOAD:Negrito" title="Negrito">Negrito</a></span></span><span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping unexpected msDict in sense <span class="msDict x_xd1 t_core" id="m_en_gbus0967720.004"><span class="df" role="text">forming adjectives meaning<span class="gp tg_df">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:dictionary_definition:Silently ignoring example without corresponding definition <span class="msDict x_xo2 t_core" id="m_en_gbus1028170.133"><span class="eg" role="text"><span class="ex"> someone will have to talk to Lily</span><span class="gp tg_eg">. </span></span></span>
# WARNING:root:Too many topics found: [<span class="lg"><span class="ge">British</span></span>, <span class="lg" role="text"><span class="reg">informal </span></span>], picking first one
# WARNING:root:Too many topics found: [<span class="lg">or <span class="ge">British </span></span>, <span class="lg" role="text"><span class="sj">Law </span></span>], picking first one
# /root/miniconda3/envs/company-makeup/lib/python3.7/site-packages/bs4/__init__.py:314: UserWarning: "b'work'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# WARNING:dictionary_definition:Invalid entry :
# Error rate: 0.0

# %%
random.shuffle(parsed)
with open(f"data/en_dictionary_parsed_randomized.pickle", "wb") as f:
    pickle.dump(parsed, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
error_titles = []
num_choices = 200000
for title, parsed_entry in random.choices(parsies_items, k=num_choices):
    try:
        dictionary_definition.AppleDictParser.parse(parsed_entry)
    except Exception:
        error_titles.append(title)
        
print(f"Error rate: {len(error_titles) / num_choices}")
# Out:
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0006560.016" role="text">Acids are compounds that release hydrogen ions (H<span class="sup">+</span>) when dissolved in water. Any solution with a pH of less than 7 is acidic, strong acids such as sulfuric or hydrochloric acid having a pH as low as 1 or 2. Most organic acids (<span class="ll" id="m_en_gbus0006560.017">carboxylic</span> or <span class="ll" id="m_en_gbus0006560.018">fatty acids</span>) contain the carboxyl group −COOH<span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0151780.017" role="text">Compounds of carbon (organic compounds) form the physical basis of all living organisms. Carbon atoms are able to link with each other and with other atoms to form chains and rings, and an infinite variety of carbon compounds exist<span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0006560.016" role="text">Acids are compounds that release hydrogen ions (H<span class="sup">+</span>) when dissolved in water. Any solution with a pH of less than 7 is acidic, strong acids such as sulfuric or hydrochloric acid having a pH as low as 1 or 2. Most organic acids (<span class="ll" id="m_en_gbus0006560.017">carboxylic</span> or <span class="ll" id="m_en_gbus0006560.018">fatty acids</span>) contain the carboxyl group −COOH<span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Silently ignoring example without corresponding definition <span class="msDict x_xd1 hasSn t_subsense" d:abs="1" id="m_en_gbus0360630.034"><span class="gp sn tg_msDict" role="text">  • </span><span class="eg" role="text"><span class="gg" role="text"><span class="gp tg_gg">[</span>no <span class="sy">object</span><span class="gp tg_gg">] </span></span><span class="ex"><span class="lbl">:  </span>we fought and died for this country</span><span class="gp tg_eg">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:root:Too many topics found: [<span class="lg"><span class="ge">British</span></span>, <span class="lg" role="text"><span class="reg">informal </span></span>], picking first one
# WARNING:dictionary_definition:Silently ignoring example without corresponding definition <span class="msDict x_xd1 hasSn t_subsense" d:abs="1" id="m_en_gbus0360630.034"><span class="gp sn tg_msDict" role="text">  • </span><span class="eg" role="text"><span class="gg" role="text"><span class="gp tg_gg">[</span>no <span class="sy">object</span><span class="gp tg_gg">] </span></span><span class="ex"><span class="lbl">:  </span>we fought and died for this country</span><span class="gp tg_eg">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0151780.017" role="text">Compounds of carbon (organic compounds) form the physical basis of all living organisms. Carbon atoms are able to link with each other and with other atoms to form chains and rings, and an infinite variety of carbon compounds exist<span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0151780.017" role="text">Compounds of carbon (organic compounds) form the physical basis of all living organisms. Carbon atoms are able to link with each other and with other atoms to form chains and rings, and an infinite variety of carbon compounds exist<span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0832580.021" role="text">Pygmies (e.g., the Mbuti and Twa peoples) are typically dark-skinned, nomadic hunter-gatherers with an average male height not above 150 cm (4 ft. 11 in.)<span class="xrg">. See also <span class="xr"><a href="x-dictionary:r:m_en_gbus0683870:com.apple.dictionary.NOAD:Negrillo" title="Negrillo">Negrillo</a></span>, <span class="xr"><a href="x-dictionary:r:m_en_gbus0683890:com.apple.dictionary.NOAD:Negrito" title="Negrito">Negrito</a></span></span><span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping unexpected msDict in sense <span class="msDict x_xd1 t_core" id="m_en_gbus0428830.004"><span class="df" role="text">in nouns denoting<span class="gp tg_df">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:dictionary_definition:Dropping unexpected msDict in sense <span class="msDict x_xd1 t_core" id="m_en_gbus0428830.004"><span class="df" role="text">in nouns denoting<span class="gp tg_df">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:root:Too many topics found: [<span class="lg"><span class="ge">British</span></span>, <span class="lg" role="text"><span class="reg">informal </span></span>], picking first one
# WARNING:root:Too many topics found: [<span class="lg">or <span class="ge">British </span></span>, <span class="lg" role="text"><span class="sj">Law </span></span>], picking first one
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0151780.017" role="text">Compounds of carbon (organic compounds) form the physical basis of all living organisms. Carbon atoms are able to link with each other and with other atoms to form chains and rings, and an infinite variety of carbon compounds exist<span class="gp tg_note">.</span></span>
# WARNING:root:Too many topics found: [<span class="lg">or <span class="ge">Scottish </span></span>, <span class="lg" role="text"><span class="ge">British </span></span>], picking first one
# WARNING:root:Too many topics found: [<span class="lg">or <span class="ge">British </span></span>, <span class="lg" role="text"><span class="sj">Law </span></span>], picking first one
# WARNING:root:Too many topics found: [<span class="lg">or <span class="ge">US</span></span>, <span class="lg" role="text"><span class="sj">Farming </span></span>], picking first one
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0006560.016" role="text">Acids are compounds that release hydrogen ions (H<span class="sup">+</span>) when dissolved in water. Any solution with a pH of less than 7 is acidic, strong acids such as sulfuric or hydrochloric acid having a pH as low as 1 or 2. Most organic acids (<span class="ll" id="m_en_gbus0006560.017">carboxylic</span> or <span class="ll" id="m_en_gbus0006560.018">fatty acids</span>) contain the carboxyl group −COOH<span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Silently ignoring example without corresponding definition <span class="msDict x_xd1 hasSn t_subsense" d:abs="1" id="m_en_gbus0360630.034"><span class="gp sn tg_msDict" role="text">  • </span><span class="eg" role="text"><span class="gg" role="text"><span class="gp tg_gg">[</span>no <span class="sy">object</span><span class="gp tg_gg">] </span></span><span class="ex"><span class="lbl">:  </span>we fought and died for this country</span><span class="gp tg_eg">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0832580.021" role="text">Pygmies (e.g., the Mbuti and Twa peoples) are typically dark-skinned, nomadic hunter-gatherers with an average male height not above 150 cm (4 ft. 11 in.)<span class="xrg">. See also <span class="xr"><a href="x-dictionary:r:m_en_gbus0683870:com.apple.dictionary.NOAD:Negrillo" title="Negrillo">Negrillo</a></span>, <span class="xr"><a href="x-dictionary:r:m_en_gbus0683890:com.apple.dictionary.NOAD:Negrito" title="Negrito">Negrito</a></span></span><span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping unexpected msDict in sense <span class="msDict x_xd1 t_core" id="m_en_gbus0428830.004"><span class="df" role="text">in nouns denoting<span class="gp tg_df">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:dictionary_definition:Silently ignoring example without corresponding definition <span class="msDict x_xd1 hasSn t_subsense" d:abs="1" id="m_en_gbus0360630.034"><span class="gp sn tg_msDict" role="text">  • </span><span class="eg" role="text"><span class="gg" role="text"><span class="gp tg_gg">[</span>no <span class="sy">object</span><span class="gp tg_gg">] </span></span><span class="ex"><span class="lbl">:  </span>we fought and died for this country</span><span class="gp tg_eg">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0151780.017" role="text">Compounds of carbon (organic compounds) form the physical basis of all living organisms. Carbon atoms are able to link with each other and with other atoms to form chains and rings, and an infinite variety of carbon compounds exist<span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0832580.021" role="text">Pygmies (e.g., the Mbuti and Twa peoples) are typically dark-skinned, nomadic hunter-gatherers with an average male height not above 150 cm (4 ft. 11 in.)<span class="xrg">. See also <span class="xr"><a href="x-dictionary:r:m_en_gbus0683870:com.apple.dictionary.NOAD:Negrillo" title="Negrillo">Negrillo</a></span>, <span class="xr"><a href="x-dictionary:r:m_en_gbus0683890:com.apple.dictionary.NOAD:Negrito" title="Negrito">Negrito</a></span></span><span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0151780.017" role="text">Compounds of carbon (organic compounds) form the physical basis of all living organisms. Carbon atoms are able to link with each other and with other atoms to form chains and rings, and an infinite variety of carbon compounds exist<span class="gp tg_note">.</span></span>
# WARNING:dictionary_definition:Dropping unexpected msDict in sense <span class="msDict x_xd1 t_core" id="m_en_gbus0428830.004"><span class="df" role="text">in nouns denoting<span class="gp tg_df">. </span></span><span class="gp tg_msDict" role="text"> </span></span>
# WARNING:root:Too many topics found: [<span class="lg"><span class="ge">British</span></span>, <span class="lg" role="text"><span class="reg">informal </span></span>], picking first one
# WARNING:dictionary_definition:Silently ignoring example without corresponding definition <span class="msDict x_xo2 t_core" id="m_en_gbus1028170.133"><span class="eg" role="text"><span class="ex"> someone will have to talk to Lily</span><span class="gp tg_eg">. </span></span></span>
# WARNING:dictionary_definition:Dropping note in word sense <span class="note x_xd1" id="m_en_gbus0555550.012" role="text">Restrictions on the foods suitable for Jews are derived from rules in the books of Leviticus and Deuteronomy. Animals must be slaughtered and prepared in the prescribed way, in which the blood is drained from the body, while certain creatures, notably pigs and shellfish, are forbidden altogether. Meat and milk must not be cooked or consumed together, and separate utensils must be kept for each. Strict observance of these rules is today confined mainly to Orthodox Jews<span class="gp tg_note">.</span></span>
# Error rate: 0.0

# %%
error_titles
# Out:
# ['-graphy', 'term', 'come']

# %%
# view = next(e for e in all_defs if e.title == "view")
# machinate = next(e for e in all_defs if e.title == "machinate")
    # parsed_entry = try_word


view = parsies["view"]
eject = parsies["eject"] 
al_desko = parsies["al desko"] 
tomato_fruitworm = parsies["tomato fruitworm"] 
technocrat = parsies["technocrat"] 
poor_law = parsies["Poor Law"] 
oh2 = parsies["oh"]
gawky = parsies["gawky"]
leo_iii = parsies["Leo III"]
pollo = parsies["pollo"]
mortimer = parsies["Mortimer, Roger de"]
sauria = parsies["Sauria"]
hardtail = parsies["hardtail"]
saccharine = parsies["saccharine"]
warren = parsies["Warren"]
rattle = parsies["rattle"]
slough_of_despond = parsies["Slough of Despond"]
try_word = parsies["try"]
eryngo = parsies["eryngo"]
fescue = parsies["fescue"]
brazen = parsies["brazen"]
weekend = parsies["weekend"]
thrash = parsies["thrash"]
thee = parsies["thee"]
talk = parsies["talk"]
beef = parsies["beef"]
pygmy = parsies["pygmy"]
kosher = parsies["kosher"]
graphy = parsies["-graphy"]
term = parsies["term"]
come = parsies["come"]
    
for i in range(10):
    title, parsed_entry = random.choice(parsies_items)
    # d = machinate
    # d = view
    # d = eject
    # d = al_desko
    # d = tomato_fruitworm
    # d = technocrat
    # parsed_entry = view
    # parsed_entry = poor_law
    # parsed_entry = oh2
    # parsed_entry = gawky
    # parsed_entry = leo_iii
    # parsed_entry = pollo
    # parsed_entry = mortimer
    # parsed_entry = sauria
    # parsed_entry = hardtail
    # parsed_entry = saccharine
    # parsed_entry = warren
    # parsed_entry = rattle
    # parsed_entry = slough_of_despond
    # parsed_entry = try_word
    # parsed_entry = beef
    # parsed_entry = term
    parsed_entry = come
    print(parsed_entry.get_text())    
    print()
    
    # print(parsed_entry.prettify())
    print(dictionary_definition.AppleDictParser.parse(parsed_entry))
    
    print()
    print(parsed_entry.prettify())
    
    print()
    print()
# Out:
# WARNING:root:Too many topics found: [<span class="lg">or <span class="ge">British </span></span>, <span class="lg">or <span class="ge">US </span></span>], picking first one
# WARNING:root:Too many topics found: [<span class="lg">or <span class="ge">British </span></span>, <span class="lg">or <span class="ge">US </span></span>], picking first one
# come  | kəmkəm | verb (past came  | kām | ; past participle come) [no object]   1 move or travel toward or into a place thought of as near or familiar to the speaker:  Jessica came into the kitchen |  they came here as immigrants |  he came rushing out.    • arrive at a specified place:  we walked along till we came to a stream |  it was very late when she came back |  my trunk hasn't come yet.    • (of a thing) reach or extend to a specified point:  women in slim dresses that came all the way to their shoes |  the path comes straight down.    • (be coming) approach:  someone was coming |  she heard the train coming.    • travel in order to be with a specified person, to do a specified thing, or to be present at an event:  the police came |  come and live with me |  the electrician came to fix the stove | figurative :  we have certainly come a long way since Aristotle.    • join someone in participating in a specified activity or course of action:  do you want to come fishing tomorrow?    • (come along/on) make progress; develop:  he's coming along nicely |  she asked them how their garden was coming on.    • (also come, come!) [in imperative] said to someone when correcting, reassuring, or urging them on:  “Come, come, child, no need to thank me.”.    2 occur; happen; take place:  twilight had not yet come |  a chance like this doesn't come along every day |  waiting for a crash that never came.    • be heard, perceived, or experienced:  a voice came from the kitchen |  it came as a great shock |  “No,” came the reply.    • (of a quality) become apparent or noticeable through actions or performance:  as an actor your style and personality must come through.    • (come across or British over or US off) (of a person) appear or sound in a specified way; give a specified impression:  he'd always come across as a decent guy.    • (of a thought or memory) enter one's mind:  the basic idea came to me while reading an article |  a passage from a novel came back to Adam.    3 take or occupy a specified position in space, order, or priority:  prisons come far down the list of priorities |  I make sure my kids come first.    • achieve a specified place in a race or contest:  she came second among sixty contestants.    4 pass into a specified state, especially one of separation or disunion:  his shirt had come undone.    • (come to/into) reach or be brought to a specified situation or result:  you will come to no harm |  staff who come into contact with the public.    • reach eventually a certain condition or state of mind:  he had come to realize she was no puppet.    5 be sold, available, or found in a specified form:  the cars come with a variety of extras |  they come in three sizes.    6 informal have an orgasm.  preposition informal when a specified time is reached or event happens:  I don't think that they'll be far away from honors come the new season.  noun informal semen ejaculated at an orgasm.  PHRASES as —— as they come used to describe someone or something that is a supreme example of the quality specified:  Smith is as tough as they come.  come again? informal used to ask someone to repeat or explain something they have said.  come and go arrive and then depart again; move around freely.    • exist or be present for a limited time; be transitory:  health fads come and go.  come from behind win after lagging.  come off it [in imperative] informal said when vigorously expressing disbelief.  come to nothing have no significant or successful result in the end.  come to pass chiefly literary happen; occur:  it came to pass that she had two sons.  come to that (or if it comes to that) British informal in fact (said to introduce an additional point):  there isn't a clock on the mantelpiece—come to that, there isn't a mantelpiece!  come to think of it on reflection (said when an idea or point occurs to one while one is speaking).  come what may no matter what happens.  have it coming (to one) informal be due for retribution on acc ...
#
# Entry(word='come', variant=None, senses=[Sense(pos='verb', definitions=[[Definition(pos_modifier=None, definition='move or travel toward or into a place thought of as near or familiar to the speaker', examples=['Jessica came into the kitchen', 'they came here as immigrants', 'he came rushing out'], topic=[], dates=[]), Definition(pos_modifier=None, definition='arrive at a specified place', examples=['we walked along till we came to a stream', 'it was very late when she came back', "my trunk hasn't come yet"], topic=[], dates=[]), Definition(pos_modifier=None, definition='(of a thing) reach or extend to a specified point', examples=['women in slim dresses that came all the way to their shoes', 'the path comes straight down'], topic=[], dates=[]), Definition(pos_modifier=None, definition='approach', examples=['someone was coming', 'she heard the train coming'], topic=[], dates=[]), Definition(pos_modifier=None, definition='travel in order to be with a specified person, to do a specified thing, or to be present at an event', examples=['the police came', 'come and live with me', 'the electrician came to fix the stove', 'we have certainly come a long way since Aristotle'], topic=[], dates=[]), Definition(pos_modifier=None, definition='join someone in participating in a specified activity or course of action', examples=['do you want to come fishing tomorrow?'], topic=[], dates=[]), Definition(pos_modifier=None, definition='make progress; develop', examples=["he's coming along nicely", 'she asked them how their garden was coming on'], topic=[], dates=[]), Definition(pos_modifier='[in imperative]', definition='said to someone when correcting, reassuring, or urging them on', examples=['“Come, come, child, no need to thank me.”'], topic=[], dates=[])], [Definition(pos_modifier=None, definition='occur; happen; take place', examples=['twilight had not yet come', "a chance like this doesn't come along every day", 'waiting for a crash that never came'], topic=[], dates=[]), Definition(pos_modifier=None, definition='be heard, perceived, or experienced', examples=['a voice came from the kitchen', 'it came as a great shock', '“No,” came the reply'], topic=[], dates=[]), Definition(pos_modifier=None, definition='(of a quality) become apparent or noticeable through actions or performance', examples=['as an actor your style and personality must come through'], topic=[], dates=[]), Definition(pos_modifier=None, definition='(of a person) appear or sound in a specified way; give a specified impression', examples=["he'd always come across as a decent guy"], topic='or British', dates=[]), Definition(pos_modifier=None, definition="(of a thought or memory) enter one's mind", examples=['the basic idea came to me while reading an article', 'a passage from a novel came back to Adam'], topic=[], dates=[])], [Definition(pos_modifier=None, definition='take or occupy a specified position in space, order, or priority', examples=['prisons come far down the list of priorities', 'I make sure my kids come first'], topic=[], dates=[]), Definition(pos_modifier=None, definition='achieve a specified place in a race or contest', examples=['she came second among sixty contestants'], topic=[], dates=[])], [Definition(pos_modifier=None, definition='pass into a specified state, especially one of separation or disunion', examples=['his shirt had come undone'], topic=[], dates=[]), Definition(pos_modifier=None, definition='reach or be brought to a specified situation or result', examples=['you will come to no harm', 'staff who come into contact with the public'], topic=[], dates=[]), Definition(pos_modifier=None, definition='reach eventually a certain condition or state of mind', examples=['he had come to realize she was no puppet'], topic=[], dates=[])], [Definition(pos_modifier=None, definition='be sold, available, or found in a specified form', examples=['the cars come with a variety of extras', 'they come in three sizes'], topic=[], dates=[])], [Definition(pos_modifier=No ...
#
# <d:entry class="entry" d:title="come" id="m_en_gbus0202180" xmlns:d="http://www.apple.com/DTDs/DictionaryService-1.0.rng">
#  <span class="hg x_xh0">
#   <span class="hw" d:dhw="1" role="text">
#    come
#   </span>
#   <span class="prx" dialect="AmE" prlexid="pron0011562.002" prxid="come_us_nvx">
#    |
#    <span class="ph t_respell" d:pr="US" dialect="AmE" id="m_en_gbus0202180.305">
#     kəm
#    </span>
#    <span class="ph" d:pr="IPA" dialect="AmE" id="m_en_gbus0202180.305" media="online" soundfile="come#_us_1">
#     kəm
#    </span>
#    |
#   </span>
#  </span>
#  <span class="sg">
#   <span class="se1 x_xd0" id="m_en_gbus0202180.004">
#    <span class="x_xdh">
#     <span class="posg" role="text">
#      <span class="pos" d:ps="1">
#       <span class="gp tg_pos">
#        verb
#       </span>
#      </span>
#      <span class="infg">
#       <span class="gp tg_infg">
#        (
#       </span>
#       <span class="sy">
#        past
#       </span>
#       <span class="inf">
#        came
#       </span>
#       <span class="pr">
#        |
#        <span class="ph t_respell" d:pr="US solitary" id="m_en_gbus0202180.006">
#         kām
#        </span>
#        |
#       </span>
#       ;
#       <span class="sy">
#        past participle
#       </span>
#       <span class="inf">
#        come
#       </span>
#       <span class="pr">
#       </span>
#       <span class="gp tg_infg">
#        )
#       </span>
#      </span>
#     </span>
#     <span class="gg" role="text">
#      <span class="gp tg_gg">
#       [
#      </span>
#      no
#      <span class="sy">
#       object
#      </span>
#      <span class="gp tg_gg">
#       ]
#      </span>
#     </span>
#    </span>
#    <span class="se2 x_xd1 hasSn" d:abs="1" id="m_en_gbus0202180.009">
#     <span class="gp x_xdh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xd1sub t_first" id="m_en_gbus0202180.010">
#      <span class="df" role="text">
#       move or travel toward or into a place thought of as near or familiar to the speaker
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        Jessica came into the kitchen
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        they came here as immigrants
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        he came rushing out
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.016">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       arrive at a specified place
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        we walked along till we
#        <span class="bold">
#         came to
#        </span>
#        a stream
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        it was very late when she
#        <span class="bold">
#         came back
#        </span>
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        my trunk hasn't come yet
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.017">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       (of a thing) reach or extend to a specified point
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        women in slim dresses that came all the way to their shoes
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        the path comes straight down
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.018">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="fg" role="text">
#       <span class="gp tg_fg">
#        (
#       </span>
#       <span class="f">
#        be coming
#       </span>
#       <span class="gp tg_fg">
#        )
#       </span>
#      </span>
#      <span class="df" role="text">
#       approach
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        someone was coming
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        she heard the train coming
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.020">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       travel in order to be with a specified person, to do a specified thing, or to be present at an event
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        the police came
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        <span class="bold">
#         come and
#        </span>
#        live with me
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        the electrician came to fix the stove
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="lg">
#        <span class="reg">
#         figurative
#        </span>
#       </span>
#       <span class="ex">
#        <span class="lbl">
#         :
#        </span>
#        we have certainly come a long way since Aristotle
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.021">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       join someone in participating in a specified activity or course of action
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        do you want to come fishing tomorrow?
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.022">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="fg" role="text">
#       <span class="gp tg_fg">
#        (
#       </span>
#       <span class="f">
#        come along/on
#       </span>
#       <span class="gp tg_fg">
#        )
#       </span>
#      </span>
#      <span class="df" role="text">
#       make progress; develop
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        he's coming along nicely
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        she asked them how their garden was coming on
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.023">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="vg" role="text">
#       <span class="gp tg_vg">
#        (
#       </span>
#       also
#       <span class="v" id="m_en_gbus0202180.306">
#        come, come!
#       </span>
#       <span class="gp tg_vg">
#        )
#       </span>
#      </span>
#      <span class="gg" role="text">
#       <span class="gp tg_gg">
#        [
#       </span>
#       in
#       <span class="sy">
#        imperative
#       </span>
#       <span class="gp tg_gg">
#        ]
#       </span>
#      </span>
#      <span class="df" role="text">
#       said to someone when correcting, reassuring, or urging them on
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        “Come, come, child, no need to thank me.”
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xdt tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xd1 hasSn" d:abs="1" id="m_en_gbus0202180.024">
#     <span class="gp x_xdh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xd1sub t_first" id="m_en_gbus0202180.025">
#      <span class="df" role="text">
#       occur; happen; take place
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        twilight had not yet come
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        a chance like this doesn't
#        <span class="bold">
#         come along
#        </span>
#        every day
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        waiting for a crash that never came
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.026">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       be heard, perceived, or experienced
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        a voice came from the kitchen
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        it
#        <span class="bold">
#         came as
#        </span>
#        a great shock
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        “No,” came the reply
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.027">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       (of a quality) become apparent or noticeable through actions or performance
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        as an actor your style and personality must
#        <span class="bold">
#         come through
#        </span>
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.028">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="fg" role="text">
#       <span class="gp tg_fg">
#        (
#       </span>
#       <span class="f">
#        come across
#       </span>
#       <span class="lg">
#        or
#        <span class="ge">
#         British
#        </span>
#       </span>
#       <span class="f">
#        over
#       </span>
#       <span class="lg">
#        or
#        <span class="ge">
#         US
#        </span>
#       </span>
#       <span class="f">
#        off
#       </span>
#       <span class="gp tg_fg">
#        )
#       </span>
#      </span>
#      <span class="df" role="text">
#       (of a person) appear or sound in a specified way; give a specified impression
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        he'd always
#        <span class="bold">
#         come across as
#        </span>
#        a decent guy
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.029">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       (of a thought or memory) enter one's mind
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        the basic idea
#        <span class="bold">
#         came to
#        </span>
#        me while reading an article
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        a passage from a novel
#        <span class="bold">
#         came back to
#        </span>
#        Adam
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xdt tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xd1 hasSn" d:abs="1" id="m_en_gbus0202180.030">
#     <span class="gp x_xdh sn ty_label tg_se2">
#      3
#     </span>
#     <span class="msDict x_xd1sub t_first" id="m_en_gbus0202180.031">
#      <span class="df" role="text">
#       take or occupy a specified position in space, order, or priority
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        prisons come far down the list of priorities
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        I make sure my kids come first
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.032">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       achieve a specified place in a race or contest
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        she came second among sixty contestants
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xdt tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xd1 hasSn" d:abs="1" id="m_en_gbus0202180.033">
#     <span class="gp x_xdh sn ty_label tg_se2">
#      4
#     </span>
#     <span class="msDict x_xd1sub t_first" id="m_en_gbus0202180.034">
#      <span class="df" role="text">
#       pass into a specified state, especially one of separation or disunion
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        his shirt had come undone
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.035">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="fg" role="text">
#       <span class="gp tg_fg">
#        (
#       </span>
#       <span class="f">
#        come to/into
#       </span>
#       <span class="gp tg_fg">
#        )
#       </span>
#      </span>
#      <span class="df" role="text">
#       reach or be brought to a specified situation or result
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        you will come to no harm
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        staff who come into contact with the public
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xd1sub hasSn t_subsense" id="m_en_gbus0202180.036">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       reach eventually a certain condition or state of mind
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        he had come to realize she was no puppet
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xdt tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xd1 hasSn" d:abs="1" id="m_en_gbus0202180.037">
#     <span class="gp x_xdh sn ty_label tg_se2">
#      5
#     </span>
#     <span class="msDict x_xd1sub t_first" id="m_en_gbus0202180.038">
#      <span class="df" role="text">
#       be sold, available, or found in a specified form
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        the cars
#        <span class="bold">
#         come with
#        </span>
#        a variety of extras
#       </span>
#       <span class="gp tg_eg">
#        |
#       </span>
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        they
#        <span class="bold">
#         come in
#        </span>
#        three sizes
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xdt tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xd1 hasSn" d:abs="1" id="m_en_gbus0202180.039">
#     <span class="gp x_xdh sn ty_label tg_se2">
#      6
#     </span>
#     <span class="msDict x_xd1sub t_first" id="m_en_gbus0202180.040">
#      <span class="lg" role="text">
#       <span class="reg">
#        informal
#       </span>
#      </span>
#      <span class="df" role="text">
#       have an orgasm
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xdt tg_se1">
#    </span>
#   </span>
#   <span class="se1 x_xd0" id="m_en_gbus0202180.041">
#    <span class="x_xdh">
#     <span class="posg" role="text">
#      <span class="pos" d:ps="1">
#       <span class="gp tg_pos">
#        preposition
#       </span>
#      </span>
#     </span>
#     <span class="lg">
#      <span class="reg">
#       informal
#      </span>
#     </span>
#    </span>
#    <span class="msDict x_xd1 t_core" id="m_en_gbus0202180.042">
#     <span class="df" role="text">
#      when a specified time is reached or event happens
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       I don't think that they'll be far away from honors come the new season
#      </span>
#      <span class="gp tg_eg">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xdt tg_se1">
#    </span>
#   </span>
#   <span class="se1 x_xd0" id="m_en_gbus0202180.044">
#    <span class="x_xdh">
#     <span class="posg" role="text">
#      <span class="pos" d:ps="1">
#       <span class="gp tg_pos">
#        noun
#       </span>
#      </span>
#     </span>
#     <span class="lg">
#      <span class="reg">
#       informal
#      </span>
#     </span>
#    </span>
#    <span class="msDict x_xd1 t_core" id="m_en_gbus0202180.045">
#     <span class="df" role="text">
#      semen ejaculated at an orgasm
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#   </span>
#   <span class="gp tg_sg">
#   </span>
#  </span>
#  <span class="subEntryBlock x_xo0 t_phrases">
#   <span class="gp x_xoLblBlk ty_label tg_subEntryBlock">
#    PHRASES
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.047">
#    <span class="l x_xoh" role="text">
#     as —— as they come
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.048">
#     <span class="df" role="text">
#      used to describe someone or something that is a supreme example of the quality specified
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       Smith is as tough as they come
#      </span>
#      <span class="gp tg_eg">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.049">
#    <span class="l x_xoh" role="text">
#     come again?
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.050">
#     <span class="lg" role="text">
#      <span class="reg">
#       informal
#      </span>
#     </span>
#     <span class="df" role="text">
#      used to ask someone to repeat or explain something they have said
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.051">
#    <span class="l x_xoh" role="text">
#     come and go
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.052">
#     <span class="df" role="text">
#      arrive and then depart again; move around freely
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#     <span class="gp tg_msDict" role="text">
#     </span>
#    </span>
#    <span class="msDict x_xo2 hasSn t_subsense" id="m_en_gbus0202180.053">
#     <span class="gp sn tg_msDict" role="text">
#      •
#     </span>
#     <span class="df" role="text">
#      exist or be present for a limited time; be transitory
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       health fads come and go
#      </span>
#      <span class="gp tg_eg">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.054">
#    <span class="l x_xoh" role="text">
#     come from behind
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.055">
#     <span class="df" role="text">
#      win after lagging
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.056">
#    <span class="l x_xoh" role="text">
#     come off it
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.057">
#     <span class="gg" role="text">
#      <span class="gp tg_gg">
#       [
#      </span>
#      in
#      <span class="sy">
#       imperative
#      </span>
#      <span class="gp tg_gg">
#       ]
#      </span>
#     </span>
#     <span class="lg" role="text">
#      <span class="reg">
#       informal
#      </span>
#     </span>
#     <span class="df" role="text">
#      said when vigorously expressing disbelief
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.062">
#    <span class="l x_xoh" role="text">
#     come to nothing
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.063">
#     <span class="df" role="text">
#      have no significant or successful result in the end
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.064">
#    <span class="l x_xoh" role="text">
#     come to pass
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.065">
#     <span class="lg" role="text">
#      chiefly
#      <span class="reg">
#       literary
#      </span>
#     </span>
#     <span class="df" role="text">
#      happen; occur
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       it
#       <span class="bold">
#        came to pass that
#       </span>
#       she had two sons
#      </span>
#      <span class="gp tg_eg">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.066">
#    <span class="l x_xoh" role="text">
#     come to that
#     <span class="vg">
#      <span class="gp tg_vg">
#       (
#      </span>
#      or
#      <span class="v" id="m_en_gbus0202180.067">
#       if it comes to that
#      </span>
#      <span class="gp tg_vg">
#       )
#      </span>
#     </span>
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.068">
#     <span class="lg" role="text">
#      <span class="ge">
#       British
#      </span>
#      <span class="reg">
#       informal
#      </span>
#     </span>
#     <span class="df" role="text">
#      in fact (said to introduce an additional point)
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       there isn't a clock on the mantelpiece—come to that, there isn't a mantelpiece!
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.069">
#    <span class="l x_xoh" role="text">
#     come to think of it
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.070">
#     <span class="df" role="text">
#      on reflection (said when an idea or point occurs to one while one is speaking)
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.071">
#    <span class="l x_xoh" role="text">
#     come what may
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.072">
#     <span class="df" role="text">
#      no matter what happens
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.073">
#    <span class="l x_xoh" role="text">
#     have it coming
#     <span class="vg">
#      <span class="gp tg_vg">
#       (
#      </span>
#      <span class="v" id="m_en_gbus0202180.074">
#       to one
#      </span>
#      <span class="gp tg_vg">
#       )
#      </span>
#     </span>
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.075">
#     <span class="lg" role="text">
#      <span class="reg">
#       informal
#      </span>
#     </span>
#     <span class="df" role="text">
#      be due for retribution on account of something bad that one has done
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       his uppity sister-in-law had it coming to her
#      </span>
#      <span class="gp tg_eg">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.076">
#    <span class="l x_xoh" role="text">
#     how come?
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.077">
#     <span class="lg" role="text">
#      <span class="reg">
#       informal
#      </span>
#     </span>
#     <span class="df" role="text">
#      said when asking how or why something happened or is the case
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       how come you never married, Jimmy?
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.078">
#    <span class="l x_xoh" role="text">
#     to come
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.079">
#     <span class="df" role="text">
#      (following a noun) in the future
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       films that would inspire generations to come
#      </span>
#      <span class="gp tg_eg">
#       |
#      </span>
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       in years to come
#      </span>
#      <span class="gp tg_eg">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.082">
#    <span class="l x_xoh" role="text">
#     where someone is coming from
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.083">
#     <span class="lg" role="text">
#      <span class="reg">
#       informal
#      </span>
#     </span>
#     <span class="df" role="text">
#      someone's meaning, motivation, or personality
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#   </span>
#  </span>
#  <span class="subEntryBlock x_xo0 t_phrasalVerbs">
#   <span class="gp x_xoLblBlk ty_label tg_subEntryBlock">
#    PHRASAL VERBS
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.086">
#    <span class="l x_xoh" role="text">
#     come about
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.087">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.088">
#      <span class="df" role="text">
#       happen; take place
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        the relative speed with which emancipation came about
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.089">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.090">
#      <span class="df" role="text">
#       (of a ship) change direction
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.097">
#    <span class="l x_xoh" role="text">
#     come across
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.098">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.099">
#      <span class="df" role="text">
#       meet or find by chance
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        I came across these old photos recently
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.100">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.101">
#      <span class="lg" role="text">
#       <span class="reg">
#        informal
#       </span>
#      </span>
#      <span class="df" role="text">
#       hand over or provide what is wanted
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        she has
#        <span class="bold">
#         come across with
#        </span>
#        some details
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xo2sub hasSn t_subsense" id="m_en_gbus0202180.102">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       (of a woman) agree to have sexual intercourse with a man
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.103">
#    <span class="l x_xoh" role="text">
#     come along
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.307">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.308">
#      <span class="df" role="text">
#       arrive
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        a chance like this doesn't come along every day
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.309">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.104">
#      <span class="gg" role="text">
#       <span class="gp tg_gg">
#        [
#       </span>
#       in
#       <span class="sy">
#        imperative
#       </span>
#       <span class="gp tg_gg">
#        ]
#       </span>
#      </span>
#      <span class="df" role="text">
#       said when encouraging someone or telling them to hurry up
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        That's our man, Watson! Come along!
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.109">
#    <span class="x_xoh">
#     <span class="l" role="text">
#      come around
#     </span>
#     <span class="vg">
#      <span class="gp tg_vg">
#       (
#      </span>
#      <span class="lg">
#       chiefly
#       <span class="ge">
#        British
#       </span>
#      </span>
#      also
#      <span class="v" id="m_en_gbus0202180.310">
#       come round
#      </span>
#      <span class="gp tg_vg">
#       )
#      </span>
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.111">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.112">
#      <span class="df" role="text">
#       recover consciousness
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        I'd just come around from a drunken stupor
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.113">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.114">
#      <span class="df" role="text">
#       be converted to another person's opinion
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        I came around to her point of view
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.115">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      3
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.116">
#      <span class="df" role="text">
#       (of a date or regular occurrence) recur; be imminent again
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        Friday had come around so quickly
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.117">
#    <span class="l x_xoh" role="text">
#     come at
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.118">
#     <span class="df" role="text">
#      launch oneself at (someone); attack
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.119">
#    <span class="l x_xoh" role="text">
#     come away
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.120">
#     <span class="df" role="text">
#      be left with a specified feeling, impression, or result after doing something
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       she came away feeling upset
#      </span>
#      <span class="gp tg_eg">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.121">
#    <span class="l x_xoh" role="text">
#     come back
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.122">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.123">
#      <span class="df" role="text">
#       (in sports) recover from a deficit
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        the Mets
#        <span class="bold">
#         came back from
#        </span>
#        a 3–0 deficit
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.124">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.125">
#      <span class="df" role="text">
#       reply or respond to someone, especially vigorously
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        he
#        <span class="bold">
#         came back at
#        </span>
#        Judy with a vengeance
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.126">
#    <span class="l x_xoh" role="text">
#     come before
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.127">
#     <span class="df" role="text">
#      be dealt with by (a judge or court)
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
#       it is the most controversial issue to come before the Supreme Court
#      </span>
#      <span class="gp tg_eg">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.128">
#    <span class="l x_xoh" role="text">
#     come between
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.129">
#     <span class="df" role="text">
#      interfere with or disturb the relationship of (two people)
#     </span>
#     <span class="gp tg_df" role="text">
#      :
#     </span>
#     <span class="eg" role="text">
#      <span class="ex">
# ...
#      <span class="df" role="text">
#       (of a stain) be removed or able to be removed
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.232">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      6
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.233">
#      <span class="lg" role="text">
#       <span class="reg">
#        informal
#       </span>
#      </span>
#      <span class="df" role="text">
#       openly declare that one is homosexual
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#      <span class="etym" role="text">
#       <span class="gp tg_etym">
#        [
#       </span>
#       from the phrase
#       <span class="italic">
#        come out of the closet
#       </span>
#       <span class="xrg">
#        (see
#        <span class="xr">
#         <a href="x-dictionary:r:m_en_gbus0191770:com.apple.dictionary.NOAD#xpointer(//*[@id='m_en_gbus0191770.011']):closet" title="closet">
#          closet
#          <span class="xrlabelGroup">
#           <span class="xrlabel">
#            <span class="gp tg_xrlabel">
#             (
#            </span>
#            <span class="gp ty_label tg_xrlabel">
#             sense
#            </span>
#            2
#           </span>
#           <span class="xrlabel">
#            <span class="gp ty_label tg_xrlabel">
#             of the
#            </span>
#            noun
#            <span class="gp tg_xrlabel">
#             )
#            </span>
#           </span>
#          </span>
#         </a>
#        </span>
#       </span>
#       )
#       <span class="gp tg_etym">
#        .
#       </span>
#       <span class="gp tg_etym">
#        ]
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.234">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      7
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.235">
#      <span class="lg" role="text">
#       <span class="ge">
#        British
#       </span>
#       <span class="reg">
#        dated
#       </span>
#      </span>
#      <span class="df" role="text">
#       (of a young upper-class woman) make one's debut in society
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.236">
#    <span class="l x_xoh" role="text">
#     come out in
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.237">
#     <span class="lg" role="text">
#      <span class="ge">
#       British
#      </span>
#     </span>
#     <span class="df" role="text">
#      (of a person's skin) break out in (pimples or a similar condition)
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.238">
#    <span class="l x_xoh" role="text">
#     come out with
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.239">
#     <span class="df" role="text">
#      say (something) in a sudden, rude, or incautious way
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.240">
#    <span class="l x_xoh" role="text">
#     come over
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.241">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.242">
#      <span class="df" role="text">
#       (of a feeling or manner) begin to affect (someone)
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.244">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.245">
#      <span class="df" role="text">
#       change to another side or point of view
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.254">
#    <span class="l x_xoh" role="text">
#     come round
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.255">
#     <span class="xrg" role="text">
#      see
#      <span class="xr">
#       come around
#      </span>
#      <span class="gp tg_xrg">
#       .
#      </span>
#     </span>
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.256">
#    <span class="l x_xoh" role="text">
#     come through
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.257">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.258">
#      <span class="df" role="text">
#       succeed in surviving or dealing with (an illness or ordeal)
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        she's come through the operation very well
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.259">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.260">
#      <span class="df" role="text">
#       (of a message) be sent and received
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xo2sub hasSn t_subsense" id="m_en_gbus0202180.261">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       (of an official decree) be processed and notified
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.269">
#    <span class="l x_xoh" role="text">
#     come to
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.270">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.271">
#      <span class="fg" role="text">
#       <span class="gp tg_fg">
#        (
#       </span>
#       also
#       <span class="f">
#        come to oneself
#       </span>
#       <span class="gp tg_fg">
#        )
#       </span>
#      </span>
#      <span class="df" role="text">
#       recover consciousness
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.272">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.273">
#      <span class="df" role="text">
#       (of an expense) reach in total; amount to
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        he hasn't the least idea of how much it will come to
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.274">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      3
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.275">
#      <span class="df" role="text">
#       (of a ship) come to a stop
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.276">
#    <span class="l x_xoh" role="text">
#     come under
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.277">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.278">
#      <span class="df" role="text">
#       be classified as or among
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        they all come under the general heading of opinion polls
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.279">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.280">
#      <span class="df" role="text">
#       be subject to (an influence or authority)
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xo2sub hasSn t_subsense" id="m_en_gbus0202180.281">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       be subjected to (pressure or aggression)
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        his vehicle came under mortar fire
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.282">
#    <span class="l x_xoh" role="text">
#     come up
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.283">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.284">
#      <span class="df" role="text">
#       (of an issue, situation, or problem) occur or present itself, especially unexpectedly
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xo2sub hasSn t_subsense" id="m_en_gbus0202180.285">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       (of a specified time or event) approach or draw near
#      </span>
#      <span class="gp tg_df" role="text">
#       :
#      </span>
#      <span class="eg" role="text">
#       <span class="ex">
#        she's got exams coming up
#       </span>
#       <span class="gp tg_eg">
#        .
#       </span>
#      </span>
#      <span class="gp tg_msDict" role="text">
#      </span>
#     </span>
#     <span class="msDict x_xo2sub hasSn t_subsense" id="m_en_gbus0202180.286">
#      <span class="gp sn tg_msDict" role="text">
#       •
#      </span>
#      <span class="df" role="text">
#       (of a legal case) reach the time when it is scheduled to be dealt with
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.289">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.290">
#      <span class="lg" role="text">
#       <span class="ge">
#        British
#       </span>
#      </span>
#      <span class="df" role="text">
#       begin one's studies at a university, especially Oxford or Cambridge
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.291">
#    <span class="l x_xoh" role="text">
#     come up against
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.292">
#     <span class="df" role="text">
#      be faced with or opposed by (something such as an enemy or problem)
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.293">
#    <span class="l x_xoh" role="text">
#     come up with
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.294">
#     <span class="df" role="text">
#      produce (something), especially when pressured or challenged
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.295">
#    <span class="l x_xoh" role="text">
#     come upon
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.296">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      1
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.297">
#      <span class="df" role="text">
#       attack by surprise
#       <span class="gp tg_df">
#        .
#       </span>
#      </span>
#     </span>
#     <span class="gp x_xot tg_se2">
#     </span>
#    </span>
#    <span class="se2 x_xo2 hasSn" id="m_en_gbus0202180.298">
#     <span class="gp x_xoh sn ty_label tg_se2">
#      2
#     </span>
#     <span class="msDict x_xo2sub t_first" id="m_en_gbus0202180.299">
#      <span class="xrg" role="text">
#       see
#       <span class="xr">
#        come on
#        <span class="xrlabelGroup">
#         <span class="xrlabel">
#          <span class="gp tg_xrlabel">
#           (
#          </span>
#          <span class="gp ty_label tg_xrlabel">
#           sense
#          </span>
#          2
#          <span class="gp tg_xrlabel">
#           )
#          </span>
#         </span>
#         <span class="xrlabel">
#         </span>
#        </span>
#       </span>
#       <span class="gp tg_xrg">
#        .
#       </span>
#      </span>
#     </span>
#    </span>
#    <span class="gp x_xot tg_subEntry">
#    </span>
#   </span>
#   <span class="subEntry x_xo1" id="m_en_gbus0202180.300">
#    <span class="l x_xoh" role="text">
#     come after
#    </span>
#    <span class="msDict x_xo2 t_core" id="m_en_gbus0202180.301">
#     <span class="df" role="text">
#      pursue or hunt down (someone)
#      <span class="gp tg_df">
#       .
#      </span>
#     </span>
#    </span>
#   </span>
#  </span>
#  <span class="etym x_xo0" role="text">
#   <span class="gp x_xoLblBlk ty_label tg_etym">
#    ORIGIN
#   </span>
#   <span class="x_xo1">
#    <span class="dg">
#     <span class="date">
#      Old English
#     </span>
#    </span>
#    <span class="italic">
#     cuman
#    </span>
#    , of
#    <span class="la">
#     Germanic
#    </span>
#    origin; related to
#    <span class="la">
#     Dutch
#    </span>
#    <span class="ff">
#     komen
#    </span>
#    and
#    <span class="la">
#     German
#    </span>
#    <span class="ff">
#     kommen
#    </span>
#    <span class="gp tg_etym">
#     .
#    </span>
#    <span class="gp tg_etym">
#    </span>
#   </span>
#  </span>
#  <span class="note x_xo0" id="m_en_gbus0202180.303" role="text">
#   <span class="lbl x_blk">
#    USAGE
#   </span>
#   The use of
#   <span class="bold">
#    come
#   </span>
#   followed by
#   <span class="bold">
#    and
#   </span>
#   , as in
#   <span class="eg">
#    <span class="ex">
#     <span class="bold">
#      come and
#     </span>
#     see for yourself
#    </span>
#   </span>
#   , dates back to Old English, but is seen by some as incorrect or only suitable for informal English. For more details, see
#   <span class="xrg">
#    <span class="xr">
#     <a href="x-dictionary:r:m_en_gbus0031920:com.apple.dictionary.NOAD#xpointer(//*[@id='m_en_gbus0031920.045']):and" title="and">
#      <span class="xrlabelGroup">
#       <span class="xrlabel">
#        usage
#       </span>
#      </span>
#      <span class="gp tg_xr">
#       at
#      </span>
#      and
#      <span class="xrlabelGroup">
#       <span class="xrlabel">
#       </span>
#      </span>
#     </a>
#    </span>
#   </span>
#   <span class="gp tg_note">
#    .
#   </span>
#  </span>
# </d:entry>
